# %% [markdown]
# # WELCOME TO THE NOTEBOOK
# ---

# %% [markdown]
# # Importing Modules

# %%
import pandas as pd

# %% [markdown]
# # Loading the data

# %%
data = pd.read_json("movies_dataset.json")
data
# Out:
#       color      director_name  num_critic_for_reviews  duration        gross  \
# 0     Color      James Cameron                   723.0     178.0  760505847.0
# 1     Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2     Color         Sam Mendes                   602.0     148.0  200074175.0
# 3     Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4       NaN        Doug Walker                     NaN       NaN          NaN
# ...     ...                ...                     ...       ...          ...
# 5038  Color        Scott Smith                     1.0      87.0          NaN
# 5039  Color                NaN                    43.0      43.0          NaN
# 5040  Color   Benjamin Roberds                    13.0      76.0          NaN
# 5041  Color        Daniel Hsia                    14.0     100.0      10443.0
# 5042  Color           Jon Gunn                    43.0      90.0      85222.0
#
# ...

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                             genres        star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title  \
# 0                                      Avatar
# 1    Pirates of the Caribbean: At World's End
# 2                                     Spectre
# ...

# %% [markdown]
# # Check the dataframe shape (#rows and #columns)

# %%
data.shape
# Out:
# (5043, 14)

# %% [markdown]
# # Let's check the data types of the columns

# %%
data.dtypes
# Out:
# color                      object
# director_name              object
# num_critic_for_reviews    float64
# duration                  float64
# gross                     float64
# genres                     object
# star_name                  object
# movie_title                object
# movie_imdb_link            object
# language                   object
# country                    object
# budget                    float64
# title_year                float64
# imdb_score                float64
# dtype: object

# %% [markdown]
# Column Selection

# %%
data.genres
# Out:
# 0       Action|Adventure|Fantasy|Sci-Fi
# 1              Action|Adventure|Fantasy
# 2             Action|Adventure|Thriller
# 3                       Action|Thriller
# 4                           Documentary
#                      ...
# 5038                       Comedy|Drama
# 5039       Crime|Drama|Mystery|Thriller
# 5040              Drama|Horror|Thriller
# 5041               Comedy|Drama|Romance
# 5042                        Documentary
# Name: genres, Length: 5043, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Data Preparation
# Remove some columns:
#
#    - `movie_imdb_link`
#    - `num_critic_for_reviews`
#    - `genre`

# %%
data.drop(axis = 1, columns = ["movie_imdb_link"], inplace = True)
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                             genres        star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# ...

# %%
data.drop(axis = 1, columns = ["num_critic_for_reviews", "genres"], inplace = True)
data.head()
# Out:
#    color      director_name  duration        gross        star_name  \
# 0  Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN          NaN      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                     Spectre  English      UK  245000000.0
# 3                       The Dark Knight Rises  English     USA  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#    title_year  imdb_score
# 0      2009.0         7.9
# 1      2007.0         7.1
# ...

# %% [markdown]
# Let's check the shape again

# %%
data.shape
# Out:
# (5043, 11)

# %% [markdown]
# Let's convert the dtype of `title_year` column to integer

# %%
data.title_year = data.title_year.astype("Int64")
data.head()
# Out:
#    color      director_name  duration        gross        star_name  \
# 0  Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN          NaN      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                     Spectre  English      UK  245000000.0
# 3                       The Dark Knight Rises  English     USA  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# ...

# %% [markdown]
# Let's check the dataframe again

# %%
data
# Out:
#       color      director_name  duration        gross        star_name  \
# 0     Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN          NaN      Doug Walker
# ...     ...                ...       ...          ...              ...
# 5038  Color        Scott Smith      87.0          NaN      Eric Mabius
# 5039  Color                NaN      43.0          NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0          NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0      10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0      85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# Renaming some columns:
# - changing `gross` to `movie_income`

# %%
rename_dict = {"gross": "Movie_Income"}
data.rename(columns = rename_dict, inplace = True)
data.head()
# Out:
#    color      director_name  duration  Movie_Income        star_name  \
# 0  Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN           NaN      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                     Spectre  English      UK  245000000.0
# 3                       The Dark Knight Rises  English     USA  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# ...

# %% [markdown]
#  Rename the `budget` column to `movie_budget`

# %%
data.rename(columns = {"budget":"Movie_budget"}, inplace = True)
data.head()
# Out:
#    color      director_name  duration  Movie_Income        star_name  \
# 0  Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN           NaN      Doug Walker
#
#                                   movie_title language country  Movie_budget  \
# 0                                      Avatar  English     USA   237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 2                                     Spectre  English      UK   245000000.0
# 3                       The Dark Knight Rises  English     USA   250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN           NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# ...

# %% [markdown]
# ---
# ### Data Analysis
#
#
# Let's checkout the distribution of `duration` column using a histogram.

# %%
ax = data.duration.hist(bins=20, figsize = (10,8), grid = False)
ax.set_xlabel("Movie Durations")
ax.set_ylabel("Count")
ax.set_title("Movie Duration Histogram")
# Out:
# Text(0.5, 1.0, 'Movie Duration Histogram')

# %% [markdown]
# Create a hitogram to see the distribution of `imdb_score` column

# %%
ax = data.imdb_score.hist(bins = 20, figsize = (10,8), grid= False)
ax.set_xlabel("imbd Score")
ax.set_ylabel("Count")
ax.set_title("Movie Imbd Score Histogram")
# Out:
# Text(0.5, 1.0, 'Movie Imbd Score Histogram')

# %% [markdown]
# Let's check how many movies have the `imdb_score` less than `4`.

# %%
low_movie_imdb = data[data.imdb_score < 4 ]
low_movie_imdb
# Out:
#       color       director_name  duration  Movie_Income        star_name  \
# 217   Color     Joel Schumacher     125.0   107285004.0    Michael Gough
# 267   Color         Jan de Bont     121.0    48068396.0     Jason Patric
# 273   Color            Bo Welch      82.0   100446895.0       Sean Hayes
# 313   Color               Pitof      87.0    40198710.0   Frances Conroy
# 319   Color   Lawrence Guterman      94.0    17010646.0    Jamie Kennedy
# ...     ...                 ...       ...           ...              ...
# 4988  Color   Terron R. Parsons      93.0           NaN    Richard Tyson
# 5000  Color        Travis Legge      83.0           NaN   Elissa Dowling
# 5002  Color  Collin Joseph Neal      75.0           NaN  Julianne Gabert
# 5017  Color        Travis Legge      90.0           NaN   Kristen Seavey
# 5020    NaN     Brandon Landers     143.0           NaN    Robbie Barnes
#
#                   movie_title language country  Movie_budget  title_year  \
# ...

# %%
low_movie_imdb.shape
# Out:
# (156, 11)

# %% [markdown]
# Use a histogram to visualize the distribution of movie IMdb score in that are produced in `USA`.

# %%
data[data.country == "USA"].imdb_score.hist(bins= 20, grid = False)
# Out:
# <AxesSubplot:>

# %%
ax = data[data.country == "Canada"].imdb_score.hist(bins = 20, grid = False)
ax.set_title("French Movies Imdb score Histogram")
ax.set_xlabel("Score")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = data[data.color == "Black and White"].Movie_budget.hist(bins = 10, grid = False)
ax.set_title("B&W Movie budget Histogram")
ax.set_xlabel("Budget")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'duration', 'Movie_Income', 'star_name',
#        'movie_title', 'language', 'country', 'Movie_budget', 'title_year',
#        'imdb_score'],
#       dtype='object')

# %% [markdown]
# ---
# ### Let's answer to some analytical questions
#
# Question 1 - In which year we have the `highest` and `lowest` number of movies?

# %% [markdown]
# Now finding out number of movies per year

# %%
Count_per_year = data.groupby("title_year").size()
Count_per_year.idxmax()
# Out:
# 2009

# %%
Count_per_year = data.groupby("title_year").size()
Count_per_year.idxmin()
# Out:
# 1916

# %% [markdown]
# Let's create a line chart to show the result

# %%
ax = Count_per_year.plot(figsize = (8,6))
ax.set_title("Count of movies per year")
ax.set_xlabel("Title year")
ax.set_ylabel("Count of movies")
# Out:
# Text(0, 0.5, 'Count of movies')

# %% [markdown]
# Question 2 - In which year we have `minimum` and `maximum` average `imdb_score` ?

# %% [markdown]
# Finding average imdb score per year

# %%
average_imdb = data.groupby("title_year")["imdb_score"].mean()
average_imdb
# Out:
# title_year
# 1916    8.000000
# 1920    4.800000
# 1925    8.300000
# 1927    8.300000
# 1929    7.150000
#           ...
# 2012    6.266516
# 2013    6.369620
# 2014    6.228175
# 2015    6.033628
# 2016    6.399057
# Name: imdb_score, Length: 91, dtype: float64

# %%
average_imdb.idxmax()
# Out:
# 1957

# %%
average_imdb.idxmin()
# Out:
# 1920

# %%
ax = average_imdb.plot.line(figsize = (18,8))

# %% [markdown]
# Let's Use a barchart to visualize the result

# %%
ax = average_imdb.plot.bar(figsize = (18,8))
ax.set_title("average IMDB score per year")
ax.set_ylabel("avg")
# Out:
# Text(0, 0.5, 'avg')

# %% [markdown]
#
# Question 3 - In which year we have the `minimum` and `maximum` spent movie budget?

# %%
movie_budget = data.groupby("title_year")["Movie_budget"].sum()
movie_budget
# Out:
# title_year
# 1916    3.859070e+05
# 1920    1.000000e+05
# 1925    2.450000e+05
# 1927    6.000000e+06
# 1929    3.790000e+05
#             ...
# 2012    8.146368e+09
# 2013    8.631557e+09
# 2014    8.089608e+09
# 2015    7.889754e+09
# 2016    5.267775e+09
# Name: Movie_budget, Length: 91, dtype: float64

# %%
ax = movie_budget.plot(figsize = [10,8])
ax.set_title("Movie budget per year")
ax.set_xlabel("year")
ax.set_ylabel("movie budget")
# Out:
# Text(0, 0.5, 'movie budget')

# %% [markdown]
# Question 4 - Is there any relationship between IMdb score of a movie and the movie income?
#
# To approaches to solve this question:
# - Visual Correlation Analysis
# - Generating the Correlation Matirx

# %%
df = data[["imdb_score","Movie_Income"]]
df
# Out:
#       imdb_score  Movie_Income
# 0            7.9   760505847.0
# 1            7.1   309404152.0
# 2            6.8   200074175.0
# 3            8.5   448130642.0
# 4            7.1           NaN
# ...          ...           ...
# 5038         7.7           NaN
# 5039         7.5           NaN
# 5040         6.3           NaN
# 5041         6.3       10443.0
# 5042         6.6       85222.0
#
# [5043 rows x 2 columns]

# %% [markdown]
# Let's drop the rows with `non` values

# %%
df.dropna(inplace = True)
# Out:
# /var/folders/j9/xn_rt8h90tzgzr24xkvr5y8h0000gn/T/ipykernel_65421/1791587065.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %% [markdown]
# Let's create a scatter plot to see the data

# %%
df.plot.scatter(x = "Movie_Income", y = "imdb_score",figsize = (10,10))
# Out:
# <AxesSubplot:xlabel='Movie_Income', ylabel='imdb_score'>

# %% [markdown]
# Let's generate the correlation matrix

# %%
df.corr()
# Out:
#               imdb_score  Movie_Income
# imdb_score      1.000000      0.198021
# Movie_Income    0.198021      1.000000

# %% [markdown]
# Which country has gained the highest average IMDB score according to our data?

# %%
df = data.groupby("country")["imdb_score"].mean()
df.plot.bar(figsize = (18,8))
# Out:
# <AxesSubplot:xlabel='country'>

# %% [markdown]
# How many colored and Black&White movies do we have in our dataset ?

# %%
data.groupby("color").size()
# Out:
# color
# Black and White     209
# Color              4815
# dtype: int64

# %% [markdown]
# Which Movies of Christopher Nolan has the highest IMDB score?

# %%
data[data.director_name == "Christopher Nolan"].plot.bar(x="movie_title",y="imdb_score")
# Out:
# <AxesSubplot:xlabel='movie_title'>

# %% [markdown]
# Use a line chart to visualize how many movies have been produced in USA from 2010 to 2015

# %%
data[(data.country == "USA") & (data.title_year > 2010) & (data.title_year < 2015)].groupby("title_year").size().plot()
# Out:
# <AxesSubplot:xlabel='title_year'>
